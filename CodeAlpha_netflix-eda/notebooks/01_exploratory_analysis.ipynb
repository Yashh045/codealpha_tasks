# %% [markdown]
# # Netflix Titles — Exploratory Data Analysis
#
# Analyze Netflix's catalog of movies and TV shows:
# 1. Load and inspect the dataset
# 2. Profile missing values and content types
# 3. Explore ratings, countries, genres, and durations
# 4. Visualize catalog growth and description themes

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import seaborn as sns

from src.eda_utils import (
    categorical_summary,
    correlation_matrix,
    dataset_overview,
    duration_summary,
    numeric_summary,
    top_countries,
    top_genres,
)
from src.load_data import load_netflix_data
from src.visualizations import (
    plot_boxplots_by_category,
    plot_categorical_counts,
    plot_correlation_heatmap,
    plot_counts_over_time,
    plot_description_wordcloud,
    plot_distributions,
    plot_duration_analysis,
    plot_genre_breakdown,
    plot_missing_values,
    plot_type_split,
)

sns.set_theme(style="whitegrid", palette="muted")
# %matplotlib inline

# %% [markdown]
# ## 1. Load Data

# %%
df = load_netflix_data()
df.head(10)

# %% [markdown]
# ## 2. Dataset Overview

# %%
overview = dataset_overview(df)
print(f"Shape: {overview['shape']}")
pd.Series(overview['missing_pct']).sort_values(ascending=False).head(10)

# %% [markdown]
# ## 3. Genres & Duration

# %%
top_genres(df)

# %%
duration_summary(df)

# %% [markdown]
# ## 4. Countries & Ratings

# %%
top_countries(df)

# %%
df['rating'].value_counts()

# %% [markdown]
# ## 5. Visualizations

# %%
from IPython.display import Image, display

figures = [
    plot_genre_breakdown(top_genres(df)),
    plot_duration_analysis(df),
    plot_description_wordcloud(df),
    plot_counts_over_time(df),
    plot_type_split(df),
    plot_boxplots_by_category(df, "release_year", "type"),
]

for fig_path in figures:
    print(fig_path.name)
    display(Image(filename=str(fig_path)))
